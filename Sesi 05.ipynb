# %%
import numpy as np
import pandas as pd

# %%
# https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv")

# %%
len(df)
# Out:
# 126314

# %%
df.shape
# Out:
# (126314, 23)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# 0  1300.0000  1306.7233              H            L  0.640065   NaN
# 1  1300.0000  1293.2767              A            W  0.359935   NaN
# 2  1306.7233  1297.0712              H            W  0.631101   NaN
# 3  1300.0000  1309.6521              A            L  0.368899   NaN
# 4  1300.0000  1320.3811              H            L  0.640065   NaN
#
# [5 rows x 23 columns]

# %%
pd.set_option("display.max.columns",None)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 0    Knicks       68  1300.0000  1306.7233             H           L
# 1   Huskies       66  1300.0000  1293.2767             A           W
# 2    Knicks       47  1306.7233  1297.0712             H           W
# 3     Stags       63  1300.0000  1309.6521             A           L
# 4  Capitols       50  1300.0000  1320.3811             H           L
#
#    forecast notes
# 0  0.640065   NaN
# 1  0.359935   NaN
# 2  0.631101   NaN
# 3  0.368899   NaN
# 4  0.640065   NaN

# %%
pd.set_option("display.precision",2)

# %%
df.head() # Isi n untuk tampilkan n baris pertama
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 0    Knicks       68    1300.00    1306.72             H           L
# 1   Huskies       66    1300.00    1293.28             A           W
# 2    Knicks       47    1306.72    1297.07             H           W
# 3     Stags       63    1300.00    1309.65             A           L
# 4  Capitols       50    1300.00    1320.38             H           L
#
#    forecast notes
# 0      0.64   NaN
# 1      0.36   NaN
# 2      0.63   NaN
# 3      0.37   NaN
# 4      0.64   NaN

# %%
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 126309      60.31    GSW   Warriors      103    1790.96    1809.98
# 126310      68.01    CLE  Cavaliers       91    1704.39    1700.74
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes
# 126309             H           L      0.55   NaN
# 126310             H           W      0.77   NaN
# 126311             A           L      0.23   NaN
# 126312             H           L      0.48   NaN
# 126313             A           W      0.52   NaN

# %% [markdown]
# # Displaying Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
#  17  opp_elo_i      126314 non-null  float64
#  18  opp_elo_n      126314 non-null  float64
#  19  game_location  126314 non-null  object
#  20  game_result    126314 non-null  object
#  21  forecast       126314 non-null  float64
#  22  notes          5424 non-null    object
# dtypes: float64(6), int64(7), object(10)
# memory usage: 22.2+ MB

# %% [markdown]
# # Showing Basics Statistics

# %%
df.dtypes
# Out:
# gameorder          int64
# game_id           object
# lg_id             object
# _iscopy            int64
# year_id            int64
# date_game         object
# seasongame         int64
# is_playoffs        int64
# team_id           object
# fran_id           object
# pts                int64
# elo_i            float64
# elo_n            float64
# win_equiv        float64
# opp_id            object
# opp_fran          object
# opp_pts            int64
# opp_elo_i        float64
# opp_elo_n        float64
# game_location     object
# game_result       object
# forecast         float64
# notes             object
# dtype: object

# %%
df.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# min      1091.64    1085.77      10.15       0.00    1091.64    1085.77
# 25%      1417.24    1416.99      34.10      93.00    1417.24    1416.99
# 50%      1500.95    1500.95      42.11     103.00    1500.95    1500.95
# 75%      1576.06    1576.29      49.64     112.00    1576.06    1576.29
# max      1853.10    1853.10      71.11     186.00    1853.10    1853.10
#
#         forecast
# count  126314.00
# mean        0.50
# std         0.22
# min         0.02
# 25%         0.33
# 50%         0.50
# 75%         0.67
# max         0.98

# %% [markdown]
# # Exploring Your Dataset

# %%
df["team_id"].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df["team_id"].unique()
# Out:
# array(['TRH', 'NYK', 'CHS', 'DTF', 'WSC', 'BOS', 'PRO', 'PIT', 'STB',
#        'CLR', 'PHW', 'BLB', 'INJ', 'FTW', 'MNL', 'ROC', 'TRI', 'DNN',
#        'INO', 'SHE', 'WAT', 'AND', 'SYR', 'MLH', 'STL', 'DET', 'CIN',
#        'LAL', 'CHP', 'CHZ', 'SFW', 'BAL', 'PHI', 'CHI', 'SEA', 'OAK',
#        'ANA', 'SDR', 'KEN', 'INA', 'DNR', 'DLC', 'HSM', 'NOB', 'MNM',
#        'NJA', 'PTP', 'ATL', 'MIL', 'PHO', 'NYA', 'MMF', 'MNP', 'LAS',
#        'CAR', 'WSA', 'BUF', 'CLE', 'UTS', 'FLO', 'PTC', 'POR', 'VIR',
#        'TEX', 'MMP', 'HOU', 'GSW', 'KCO', 'MMT', 'SDA', 'CAP', 'SAA',
#        'NOJ', 'DNA', 'SSL', 'MMS', 'WSB', 'KCK', 'SDS', 'IND', 'NYN',
#        'DEN', 'SAS', 'NJN', 'SDC', 'UTA', 'DAL', 'LAC', 'SAC', 'CHH',
#        'MIA', 'MIN', 'ORL', 'VAN', 'TOR', 'WAS', 'MEM', 'NOH', 'CHA',
#        'NOK', 'OKC', 'BRK', 'NOP', 'CHO'], dtype=object)

# %%
df["fran_id"].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# Steamrollers     168
# Packers           72
# Redskins          65
# Rebels            63
# Waterloo          62
# Denver            62
# Falcons           60
# Jets              60
# Ironmen           60
# Huskies           60
# Name: fran_id, dtype: int64

# %%
df.loc[df["fran_id"] == "Lakers","team_id"].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
df.loc[df["team_id"] == "MNL","date_game"].min()
# Out:
# '1/1/1949'

# %%
df.loc[df["team_id"] == "MNL","date_game"].max()
# Out:
# '4/9/1959'

# %%
df.loc[df["team_id"] == "MNL","date_game"].agg(["min","max","nunique"])
# Out:
# min        1/1/1949
# max        4/9/1959
# nunique         946
# Name: date_game, dtype: object

# %%
df.loc[df["team_id"] == "BOS","pts"].sum()
# Out:
# 626484

# %% [markdown]
# # Pandas Data Structures

# %%
revenues = pd.Series([5555,7000,1980])

# %%
revenues
# Out:
# 0    5555
# 1    7000
# 2    1980
# dtype: int64

# %%
revenues.values
# Out:
# array([5555, 7000, 1980], dtype=int64)

# %%
revenues.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
type(revenues)
# Out:
# pandas.core.series.Series

# %%
city_revenues = pd.Series([4200,8000,6500],index=["Amsterdam","Toronto","Tokyo"])
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_revenues["Tokyo"]
# Out:
# 6500

# %%
city_revenues["Toronto"]
# Out:
# 8000

# %%
city_employee_count = pd.Series({"Amsterdam":5,"Tokyo":8})
city_employee_count
# Out:
# Amsterdam    5
# Tokyo        8
# dtype: int64

# %%
city_employee_count.keys()
# Out:
# Index(['Amsterdam', 'Tokyo'], dtype='object')

# %%
"Tokyo" in city_employee_count
# Out:
# True

# %%
"New York" in city_employee_count
# Out:
# False

# %% [markdown]
# # DataFrame Objects

# %%
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_data = pd.DataFrame({"revenue":city_revenues,"employee_count":city_employee_count})
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
city_data.index
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.values
# Out:
# array([[4.2e+03, 5.0e+00],
#        [6.5e+03, 8.0e+00],
#        [8.0e+03,     nan]])

# %%
city_data.axes
# Out:
# [Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object'),
#  Index(['revenue', 'employee_count'], dtype='object')]

# %%
city_data.axes[0]
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.axes[1]
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
city_data.keys()
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
"Amsterdam" in city_data
# Out:
# False

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 0    Knicks       68    1300.00    1306.72             H           L
# 1   Huskies       66    1300.00    1293.28             A           W
# 2    Knicks       47    1306.72    1297.07             H           W
# 3     Stags       63    1300.00    1309.65             A           L
# 4  Capitols       50    1300.00    1320.38             H           L
#
#    forecast notes
# 0      0.64   NaN
# 1      0.36   NaN
# 2      0.63   NaN
# 3      0.37   NaN
# 4      0.64   NaN

# %%
df.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %%
"pts" in df.keys()
# Out:
# True

# %% [markdown]
# # Accessing Series Elements

# %%
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_revenues["Toronto"]
# Out:
# 8000

# %%
city_revenues[1]
# Out:
# 8000

# %%
city_revenues[-1]
# Out:
# 6500

# %%
city_revenues["Toronto":]
# Out:
# Toronto    8000
# Tokyo      6500
# dtype: int64

# %%
colors = pd.Series(
    ["red","purple","blue","green","yellow"],
    index = [1,2,3,5,8]
)
colors
# Out:
# 1       red
# 2    purple
# 3      blue
# 5     green
# 8    yellow
# dtype: object

# %%
colors[1]
# Out:
# 'red'

# %%
colors.iloc[3]
# Out:
# 'green'

# %%
colors.loc[8]
# Out:
# 'yellow'

# %%
colors.iloc[1:3]
# Out:
# 2    purple
# 3      blue
# dtype: object

# %%
colors.iloc[3:8]
# Out:
# 5     green
# 8    yellow
# dtype: object

# %% [markdown]
# # Accessing DataFrame Elements

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
city_data["revenue"]
# Out:
# Amsterdam    4200
# Tokyo        6500
# Toronto      8000
# Name: revenue, dtype: int64

# %%
city_data.revenue
# Out:
# Amsterdam    4200
# Tokyo        6500
# Toronto      8000
# Name: revenue, dtype: int64

# %%
toys = pd.DataFrame([
    {"name":"ball","shape":"sphere"},
    {"name":"Rubik's cube","shape":"cube"}
])
toys
# Out:
#            name   shape
# 0          ball  sphere
# 1  Rubik's cube    cube

# %%
toys.shape
# Out:
# (2, 2)

# %%
toys["shape"]
# Out:
# 0    sphere
# 1      cube
# Name: shape, dtype: object

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
city_data.loc["Amsterdam"]
# Out:
# revenue           4200.0
# employee_count       5.0
# Name: Amsterdam, dtype: float64

# %%
city_data.iloc[0]
# Out:
# revenue           4200.0
# employee_count       5.0
# Name: Amsterdam, dtype: float64

# %%
city_data.loc["Amsterdam":"Tokyo"]
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0

# %%
city_data.iloc[0:2]
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0

# %%
city_data.loc["Amsterdam":"Tokyo","employee_count"]
# Out:
# Amsterdam    5.0
# Tokyo        8.0
# Name: employee_count, dtype: float64

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 0    Knicks       68    1300.00    1306.72             H           L
# 1   Huskies       66    1300.00    1293.28             A           W
# 2    Knicks       47    1306.72    1297.07             H           W
# 3     Stags       63    1300.00    1309.65             A           L
# 4  Capitols       50    1300.00    1320.38             H           L
#
#    forecast notes
# 0      0.64   NaN
# 1      0.36   NaN
# 2      0.63   NaN
# 3      0.37   NaN
# 4      0.64   NaN

# %%
df.loc[5555:5559,["fran_id","opp_fran","pts"]]
# Out:
#       fran_id  opp_fran  pts
# 5555  Pistons  Warriors   83
# 5556  Celtics    Knicks   95
# 5557   Knicks   Celtics   74
# 5558    Kings    Sixers   81
# 5559   Sixers     Kings   86

# %% [markdown]
# # Querying Dataset

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 0    Knicks       68    1300.00    1306.72             H           L
# 1   Huskies       66    1300.00    1293.28             A           W
# 2    Knicks       47    1306.72    1297.07             H           W
# 3     Stags       63    1300.00    1309.65             A           L
# 4  Capitols       50    1300.00    1320.38             H           L
#
#    forecast notes
# 0      0.64   NaN
# 1      0.36   NaN
# 2      0.63   NaN
# 3      0.37   NaN
# 4      0.64   NaN

# %%
current_decade = df[df["year_id"] > 2010].copy()
current_decade
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 113656           1            0     MIA       Heat   80  1547.36  1543.16
# 113657           1            0     BOS    Celtics   88  1625.10  1629.30
# 113658           1            0     HOU    Rockets  110  1504.20  1502.60
# 113659           1            0     LAL     Lakers  112  1647.60  1649.20
# 113660           1            0     PHO       Suns   92  1643.02  1630.62
# ...            ...          ...     ...        ...  ...      ...      ...
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id      opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 113656      45.14    BOS       Celtics       88    1625.10    1629.30
# 113657      53.75    MIA          Heat       80    1547.36    1543.16
# 113658      40.90    LAL        Lakers      112    1647.60    1649.20
# 113659      55.61    HOU       Rockets      110    1504.20    1502.60
# 113660      53.88    POR  Trailblazers      106    1552.81    1565.22
# ...           ...    ...           ...      ...        ...        ...
# 126309      60.31    GSW      Warriors      103    1790.96    1809.98
# 126310      68.01    CLE     Cavaliers       91    1704.39    1700.74
# 126311      60.01    GSW      Warriors      104    1809.98    1813.63
# 126312      59.29    GSW      Warriors      105    1813.63    1822.29
# 126313      68.52    CLE     Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes
# 113656             A           L      0.26   NaN
# 113657             H           W      0.74   NaN
# 113658             A           L      0.20   NaN
# 113659             H           W      0.80   NaN
# 113660             A           L      0.49   NaN
# ...              ...         ...       ...   ...
# 126309             H           L      0.55   NaN
# 126310             H           W      0.77   NaN
# 126311             A           L      0.23   NaN
# 126312             H           L      0.48   NaN
# 126313             A           W      0.52   NaN
#
# [12658 rows x 23 columns]

# %%
current_decade.shape
# Out:
# (12658, 23)

# %%
games_with_notes = df[df["notes"].notnull()].copy()
games_with_notes.shape
# Out:
# (5424, 23)

# %%
ers = df[df["fran_id"].str.endswith("ers")].copy()
ers.shape
# Out:
# (27797, 23)

# %%
df[
    (df["_iscopy"] == 0) &
    (df["pts"] > 100) &
    (df["opp_pts"] > 100) &
    (df["team_id"] == "BLB")
]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 1726        864  194902260BLB   NBA        0     1949  2/26/1949          53
# 4890       2446  195301100BLB   NBA        0     1953  1/10/1953          32
# 4909       2455  195301140BLB   NBA        0     1953  1/14/1953          34
# 5208       2605  195303110BLB   NBA        0     1953  3/11/1953          66
# 5825       2913  195402220BLB   NBA        0     1954  2/22/1954          60
#
#       is_playoffs team_id    fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 1726            0     BLB  Baltimore  114  1421.94  1419.43      38.56    MNL
# 4890            0     BLB  Baltimore  126  1328.67  1356.65      25.80    BOS
# 4909            0     BLB  Baltimore  104  1349.83  1346.36      24.88    MNL
# 5208            0     BLB  Baltimore  107  1284.52  1282.24      19.58    NYK
# 5825            0     BLB  Baltimore  110  1303.75  1301.97      20.74    BOS
#
#      opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 1726   Lakers      115    1637.99    1640.49             H           L
# 4890  Celtics      105    1591.14    1563.17             H           W
# 4909   Lakers      112    1665.44    1668.91             H           L
# 5208   Knicks      113    1649.15    1651.44             H           L
# 5825  Celtics      111    1591.49    1593.27             H           L
#
#       forecast            notes
# 1726      0.34              NaN
# 4890      0.28              NaN
# 4909      0.22              NaN
# 5208      0.18     at Boston MA
# 5825      0.25  at Worcester MA

# %%
df[
    (df["_iscopy"] == 0) &
    (df["team_id"].str.startswith("LA")) &
    (df["year_id"] > 1992) &
    (df["notes"].notnull())
]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 72344      36173  199401210LAC   NBA        0     1994   1/21/1994
# 72426      36214  199401270LAC   NBA        0     1994   1/27/1994
# 73767      36884  199411050POR   NBA        0     1995   11/5/1994
# 73841      36921  199411120LAC   NBA        0     1995  11/12/1994
# 74254      37128  199412150LAC   NBA        0     1995  12/15/1994
# 74283      37142  199412170LAC   NBA        0     1995  12/17/1994
# 74722      37362  199501210LAC   NBA        0     1995   1/21/1995
# 75216      37609  199503020LAC   NBA        0     1995    3/2/1995
# 75634      37818  199504010LAC   NBA        0     1995    4/1/1995
# 76282      38142  199511160LAC   NBA        0     1996  11/16/1995
# 76506      38254  199512020LAC   NBA        0     1996   12/2/1995
# 77162      38582  199601200LAC   NBA        0     1996   1/20/1996
# 77266      38634  199601270LAC   NBA        0     1996   1/27/1996
# 77511      38756  199602170LAC   NBA        0     1996   2/17/1996
# 77657      38829  199602270LAC   NBA        0     1996   2/27/1996
# 77887      38944  199603140LAC   NBA        0     1996   3/14/1996
# 78297      39149  199604110LAC   NBA        0     1996   4/11/1996
# 79014      39508  199611300LAC   NBA        0     1997  11/30/1996
# 79240      39621  199612160LAC   NBA        0     1997  12/16/1996
# 79752      39877  199701230LAC   NBA        0     1997   1/23/1997
# 79919      39960  199702040LAC   NBA        0     1997    2/4/1997
# 80308      40155  199703060LAC   NBA        0     1997    3/6/1997
# 80849      40425  199704120LAC   NBA        0     1997   4/12/1997
# 81259      40630  199711080LAC   NBA        0     1998   11/8/1997
# 81517      40759  199711280LAC   NBA        0     1998  11/28/1997
# 81794      40898  199712180LAC   NBA        0     1998  12/18/1997
# 82273      41137  199801220LAC   NBA        0     1998   1/22/1998
# 82440      41221  199802030LAC   NBA        0     1998    2/3/1998
# 82628      41315  199802190LAC   NBA        0     1998   2/19/1998
# 82920      41461  199803120LAC   NBA        0     1998   3/12/1998
# 83474      41738  199804180LAC   NBA        0     1998   4/18/1998
# 83806      41904  199902160LAC   NBA        0     1999   2/16/1999
# 83955      41978  199902250LAC   NBA        0     1999   2/25/1999
# 83986      41994  199902270LAC   NBA        0     1999   2/27/1999
# 84444      42223  199903270LAC   NBA        0     1999   3/27/1999
# 84670      42336  199904100LAC   NBA        0     1999   4/10/1999
# 84817      42409  199904190LAC   NBA        0     1999   4/19/1999
# 95379      47690  200310300SEA   NBA        0     2004  10/30/2003
# 95384      47693  200310310LAC   NBA        0     2004  10/31/2003
#
#        seasongame  is_playoffs team_id   fran_id  pts    elo_i    elo_n  \
# 72344          37            0     LAC  Clippers   90  1387.72  1377.64
# 72426          39            0     LAC  Clippers  101  1401.38  1398.68
# 73767           2            0     LAC  Clippers   95  1373.86  1367.04
# 73841           4            0     LAC  Clippers  101  1356.21  1351.31
# 74254          21            0     LAC  Clippers   89  1316.25  1326.85
# 74283          22            0     LAC  Clippers   87  1326.85  1307.69
# 74722          39            0     LAC  Clippers   86  1294.04  1289.08
# 75216          58            0     LAC  Clippers   88  1325.14  1318.65
# 75634          73            0     LAC  Clippers  116  1293.60  1327.38
# 76282           8            0     LAC  Clippers  103  1396.59  1399.63
# 76506          16            0     LAC  Clippers   98  1400.21  1396.17
# 77162          39            0     LAC  Clippers   82  1401.71  1390.10
# 77266          41            0     LAC  Clippers   87  1393.54  1388.76
# 77511          50            0     LAC  Clippers  100  1332.11  1340.06
# 77657          55            0     LAC  Clippers   95  1328.99  1342.11
# 77887          63            0     LAC  Clippers  110  1381.56  1385.52
# 78297          77            0     LAC  Clippers  101  1395.23  1381.94
# 79014          16            0     LAC  Clippers   95  1416.72  1398.00
# 79240          24            0     LAC  Clippers  122  1400.03  1403.83
# 79752          39            0     LAC  Clippers  102  1403.31  1411.17
# 79919          44            0     LAC  Clippers  108  1415.27  1441.67
# 80308          57            0     LAC  Clippers   93  1430.59  1427.22
# 80849          78            0     LAC  Clippers  116  1443.53  1449.17
# 81259           5            0     LAC  Clippers  105  1437.93  1421.46
# 81517          15            0     LAC  Clippers   92  1382.55  1370.31
# 81794          25            0     LAC  Clippers   82  1348.13  1352.13
# 82273          42            0     LAC  Clippers   76  1344.57  1333.45
# 82440          48            0     LAC  Clippers  111  1289.86  1310.38
# 82628          53            0     LAC  Clippers   80  1289.71  1286.67
# 82920          62            0     LAC  Clippers   85  1286.15  1280.67
# 83474          82            0     LAC  Clippers   83  1233.51  1240.79
# 83806           6            0     LAC  Clippers   89  1285.07  1276.79
# 83955          10            0     LAC  Clippers  100  1253.53  1249.40
# 83986          12            0     LAC  Clippers   74  1248.09  1241.29
# 84444          27            0     LAC  Clippers  103  1254.16  1302.97
# 84670          35            0     LAC  Clippers   70  1289.79  1282.41
# 84817          41            0     LAC  Clippers   98  1313.54  1307.33
# 95379           1            0     LAC  Clippers  100  1428.09  1421.46
# 95384           2            0     LAC  Clippers  105  1421.46  1411.31
#
#        win_equiv opp_id      opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 72344      28.91    CLE     Cavaliers      106    1571.10    1581.18
# 72426      30.96    NYK        Knicks      103    1640.02    1642.72
# 73767      27.70    POR  Trailblazers      112    1550.25    1557.08
# 73841      26.25    PHO          Suns      108    1585.83    1590.73
# 74254      24.07    GSW      Warriors       82    1483.84    1473.23
# 74283      22.43    DAL     Mavericks      106    1371.42    1390.58
# 74722      20.91    SAC         Kings       92    1502.60    1507.56
# 75216      23.36    SEA       Thunder      116    1679.72    1686.20
# 75634      24.11    UTA          Jazz       98    1689.87    1656.08
# 76282      32.05    VAN     Grizzlies       98    1304.50    1301.47
# 76506      31.70    CHI         Bulls      104    1653.13    1657.17
# 77162      31.10    UTA          Jazz      106    1616.50    1628.12
# 77266      30.97    SEA       Thunder       96    1659.33    1664.11
# 77511      26.33    POR  Trailblazers       96    1498.94    1490.99
# 77657      26.52    SAS         Spurs       90    1642.09    1628.97
# 77887      30.65    DAL     Mavericks      106    1367.47    1363.51
# 78297      30.30    GSW      Warriors      111    1422.58    1435.87
# 79014      31.42    NJN          Nets      106    1342.60    1361.32
# 79240      32.00    PHO          Suns      121    1483.82    1480.01
# 79752      32.74    SEA       Thunder      100    1660.14    1652.28
# 79919      35.85    LAL        Lakers       86    1643.52    1617.11
# 80308      34.37    ORL         Magic       94    1577.69    1581.06
# 80849      36.63    DEN       Nuggets       94    1294.84    1289.21
# 81259      33.43    PHO          Suns      123    1516.18    1532.65
# 81517      28.39    NJN          Nets      104    1468.49    1480.74
# 81794      26.69    GSW      Warriors       78    1336.38    1332.38
# 82273      25.00    DET       Pistons       94    1523.62    1534.74
# 82440      23.00    UTA          Jazz      102    1660.32    1639.80
# 82628      21.04    MIA          Heat       89    1643.84    1646.88
# 82920      20.57    LAL        Lakers      108    1645.59    1651.07
# 83474      17.59    SAC         Kings       77    1317.31    1310.03
# 83806      20.06    VAN     Grizzlies       93    1305.31    1313.59
# 83955      18.01    LAL        Lakers      115    1611.34    1615.46
# 83986      17.44    ATL         Hawks      103    1598.35    1605.16
# 84444      22.16    UTA          Jazz       77    1709.66    1660.86
# 84670      20.50    POR  Trailblazers       97    1614.94    1622.32
# 84817      22.52    SAC         Kings      102    1418.43    1424.64
# 95379      32.56    SEA       Thunder      109    1523.13    1529.76
# 95384      31.54    SEA       Thunder      124    1529.76    1539.91
#
#       game_location game_result  forecast               notes
# 72344             H           L      0.38    at Inglewood, CA
# 72426             H           L      0.31      at Anaheim, CA
# 73767             N           L      0.27  at Yokohama, Japan
# 73841             H           L      0.32      at Anaheim, CA
# 74254             H           W      0.40      at Anaheim, CA
# 74283             H           L      0.58      at Anaheim, CA
# 74722             H           L      0.35      at Anaheim, CA
# 75216             H           L      0.19      at Anaheim, CA
# 75634             H           W      0.15      at Anaheim, CA
# 76282             H           W      0.75      at Anaheim, CA
# 76506             H           L      0.29      at Anaheim, CA
# 77162             H           L      0.34      at Anaheim, CA
# 77266             H           L      0.28      at Anaheim, CA
# 77511             H           W      0.40      at Anaheim, CA
# 77657             H           W      0.23      at Anaheim, CA
# 77887             H           W      0.66      at Anaheim, CA
# 78297             H           L      0.60      at Anaheim, CA
# 79014             H           L      0.73      at Anaheim, CA
# 79240             H           W      0.52      at Anaheim, CA
# 79752             H           W      0.29      at Anaheim, CA
# 79919             H           W      0.32      at Anaheim, CA
# 80308             H           L      0.43      at Anaheim, CA
# 80849             H           W      0.81      at Anaheim, CA
# 81259             H           L      0.53      at Anaheim, CA
# 81517             H           L      0.52      at Anaheim, CA
# 81794             H           W      0.66      at Anaheim, CA
# 82273             H           L      0.39      at Anaheim, CA
# 82440             H           W      0.17      at Anaheim, CA
# 82628             H           L      0.19      at Anaheim, CA
# 82920             H           L      0.18      at Anaheim, CA
# 83474             H           W      0.52      at Anaheim, CA
# 83806             H           L      0.61      at Anaheim, CA
# 83955             H           L      0.18      at Anaheim, CA
# 83986             H           L      0.19      at Anaheim, CA
# 84444             H           W      0.11      at Anaheim, CA
# 84670             H           L      0.21      at Anaheim, CA
# 84817             H           L      0.49      at Anaheim, CA
# 95379             N           L      0.37   at Saitama, Japan
# 95384             N           L      0.35   at Saitama, Japan

# %% [markdown]
# # Grouping and Aggregating Data

# %%
city_revenues.sum()
# Out:
# 18700

# %%
city_revenues.max()
# Out:
# 8000

# %%
df["pts"].sum()
# Out:
# 12976235

# %%
df.groupby("fran_id",sort = False)["pts"].sum()
# Out:
# fran_id
# Huskies           3995
# Knicks          582497
# Stags            20398
# Falcons           3797
# Capitols         22387
# Celtics         626484
# Steamrollers     12372
# Ironmen           3674
# Bombers          17793
# Rebels            4474
# Warriors        591224
# Baltimore        37219
# Jets              4482
# Pistons         572758
# Lakers          637444
# Kings           569245
# Hawks           567261
# Denver            4818
# Olympians        22864
# Redskins          5372
# Waterloo          4921
# Packers           6193
# Sixers          585891
# Wizards         474809
# Bulls           437269
# Thunder         437735
# Squires          91127
# Stars            84940
# Rockets         432504
# Colonels         94435
# Pacers          438288
# Nuggets         445780
# Spurs           453822
# Spirits          85874
# Sounds           75582
# Floridians       49568
# Nets            417809
# Condors          49642
# Bucks           418326
# Suns            437486
# Clippers        380523
# Cavaliers       380416
# Trailblazers    402695
# Sails            30080
# Jazz            363155
# Mavericks       309239
# Pelicans        220794
# Heat            229103
# Timberwolves    207693
# Magic           219436
# Grizzlies       157683
# Raptors         158370
# Hornets          84489
# Name: pts, dtype: int64

# %%
df[
    (df["fran_id"] == "Spurs") &
    (df["year_id"] > 2010)
].groupby(["year_id","game_result"])["game_id"].count()
# Out:
# year_id  game_result
# 2011     L              25
#          W              63
# 2012     L              20
#          W              60
# 2013     L              30
#          W              73
# 2014     L              27
#          W              78
# 2015     L              31
#          W              58
# Name: game_id, dtype: int64

# %%
df[
    (df["fran_id"] == "Warriors") &
    (df["year_id"] == 2015)
].groupby(["is_playoffs","game_result"])["game_id"].count()
# Out:
# is_playoffs  game_result
# 0            L              15
#              W              67
# 1            L               5
#              W              16
# Name: game_id, dtype: int64

# %% [markdown]
# # Manipulating Columns

# %%
nba = df.copy()
nba.shape
# Out:
# (126314, 23)

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# 1                1            0     NYK     Knicks   68  1300.00  1306.72
# 2                1            0     CHS      Stags   63  1300.00  1309.65
# 3                2            0     NYK     Knicks   47  1306.72  1297.07
# 4                1            0     DTF    Falcons   33  1300.00  1279.62
# ...            ...          ...     ...        ...  ...      ...      ...
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 0           40.29    NYK     Knicks       68    1300.00    1306.72
# 1           41.71    TRH    Huskies       66    1300.00    1293.28
# 2           42.01    NYK     Knicks       47    1306.72    1297.07
# 3           40.69    CHS      Stags       63    1300.00    1309.65
# 4           38.86    WSC   Capitols       50    1300.00    1320.38
# ...           ...    ...        ...      ...        ...        ...
# 126309      60.31    GSW   Warriors      103    1790.96    1809.98
# 126310      68.01    CLE  Cavaliers       91    1704.39    1700.74
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes
# 0                  H           L      0.64   NaN
# 1                  A           W      0.36   NaN
# 2                  H           W      0.63   NaN
# 3                  A           L      0.37   NaN
# 4                  H           L      0.64   NaN
# ...              ...         ...       ...   ...
# 126309             H           L      0.55   NaN
# 126310             H           W      0.77   NaN
# 126311             A           L      0.23   NaN
# 126312             H           L      0.48   NaN
# 126313             A           W      0.52   NaN
#
# [126314 rows x 23 columns]

# %%
nba["difference"] = df.pts - df.opp_pts

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 0    Knicks       68    1300.00    1306.72             H           L
# 1   Huskies       66    1300.00    1293.28             A           W
# 2    Knicks       47    1306.72    1297.07             H           W
# 3     Stags       63    1300.00    1309.65             A           L
# 4  Capitols       50    1300.00    1320.38             H           L
#
#    forecast notes  difference
# 0      0.64   NaN          -2
# 1      0.36   NaN           2
# 2      0.63   NaN          16
# 3      0.37   NaN         -16
# 4      0.64   NaN         -17

# %%
nba.shape
# Out:
# (126314, 24)

# %%
nba["difference"].max()
# Out:
# 68

# %%
nba["difference"].min()
# Out:
# -68

# %%
nba["difference"].mean()
# Out:
# 0.0

# %%
renamed_nba = nba.rename(columns = {"game_result":"result","game_location":"location"})
renamed_nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# 1                1            0     NYK     Knicks   68  1300.00  1306.72
# 2                1            0     CHS      Stags   63  1300.00  1309.65
# 3                2            0     NYK     Knicks   47  1306.72  1297.07
# 4                1            0     DTF    Falcons   33  1300.00  1279.62
# ...            ...          ...     ...        ...  ...      ...      ...
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n location  \
# 0           40.29    NYK     Knicks       68    1300.00    1306.72        H
# 1           41.71    TRH    Huskies       66    1300.00    1293.28        A
# 2           42.01    NYK     Knicks       47    1306.72    1297.07        H
# 3           40.69    CHS      Stags       63    1300.00    1309.65        A
# 4           38.86    WSC   Capitols       50    1300.00    1320.38        H
# ...           ...    ...        ...      ...        ...        ...      ...
# 126309      60.31    GSW   Warriors      103    1790.96    1809.98        H
# 126310      68.01    CLE  Cavaliers       91    1704.39    1700.74        H
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63        A
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29        H
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09        A
#
#        result  forecast notes  difference
# 0           L      0.64   NaN          -2
# 1           W      0.36   NaN           2
# 2           W      0.63   NaN          16
# 3           L      0.37   NaN         -16
# 4           L      0.64   NaN         -17
# ...       ...       ...   ...         ...
# 126309      L      0.55   NaN         -21
# 126310      W      0.77   NaN          13
# 126311      L      0.23   NaN         -13
# 126312      L      0.48   NaN          -8
# 126313      W      0.52   NaN           8
#
# [126314 rows x 24 columns]

# %%
elo_columns = ["elo_i","elo_n","opp_elo_i","opp_elo_n"]
elo_columns
# Out:
# ['elo_i', 'elo_n', 'opp_elo_i', 'opp_elo_n']

# %%
nba.drop(elo_columns,inplace = True,axis = 1)

# %%
nba.columns
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'win_equiv',
#        'opp_id', 'opp_fran', 'opp_pts', 'game_location', 'game_result',
#        'forecast', 'notes', 'difference'],
#       dtype='object')

# %% [markdown]
# # Specifying Data Types

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  win_equiv      126314 non-null  float64
#  12  opp_id         126314 non-null  object
#  13  opp_fran       126314 non-null  object
#  14  opp_pts        126314 non-null  int64
#  15  game_location  126314 non-null  object
#  16  game_result    126314 non-null  object
#  17  forecast       126314 non-null  float64
#  18  notes          5424 non-null    object
#  19  difference     126314 non-null  int64
# dtypes: float64(2), int64(8), object(10)
# memory usage: 19.3+ MB

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts  win_equiv opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies   66      40.29    NYK    Knicks       68
# 1            0     NYK   Knicks   68      41.71    TRH   Huskies       66
# 2            0     CHS    Stags   63      42.01    NYK    Knicks       47
# 3            0     NYK   Knicks   47      40.69    CHS     Stags       63
# 4            0     DTF  Falcons   33      38.86    WSC  Capitols       50
#
#   game_location game_result  forecast notes  difference
# 0             H           L      0.64   NaN          -2
# 1             A           W      0.36   NaN           2
# 2             H           W      0.63   NaN          16
# 3             A           L      0.37   NaN         -16
# 4             H           L      0.64   NaN         -17

# %%
nba["date_game"] = pd.to_datetime(nba["date_game"])
nba["date_game"]
# Out:
# 0        1946-11-01
# 1        1946-11-01
# 2        1946-11-02
# 3        1946-11-02
# 4        1946-11-02
#             ...
# 126309   2015-06-11
# 126310   2015-06-14
# 126311   2015-06-14
# 126312   2015-06-16
# 126313   2015-06-16
# Name: date_game, Length: 126314, dtype: datetime64[ns]

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947 1946-11-01           1
# 1          1  194611010TRH   NBA        1     1947 1946-11-01           1
# 2          2  194611020CHS   NBA        0     1947 1946-11-02           1
# 3          2  194611020CHS   NBA        1     1947 1946-11-02           2
# 4          3  194611020DTF   NBA        0     1947 1946-11-02           1
#
#    is_playoffs team_id  fran_id  pts  win_equiv opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies   66      40.29    NYK    Knicks       68
# 1            0     NYK   Knicks   68      41.71    TRH   Huskies       66
# 2            0     CHS    Stags   63      42.01    NYK    Knicks       47
# 3            0     NYK   Knicks   47      40.69    CHS     Stags       63
# 4            0     DTF  Falcons   33      38.86    WSC  Capitols       50
#
#   game_location game_result  forecast notes  difference
# 0             H           L      0.64   NaN          -2
# 1             A           W      0.36   NaN           2
# 2             H           W      0.63   NaN          16
# 3             A           L      0.37   NaN         -16
# 4             H           L      0.64   NaN         -17

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  win_equiv      126314 non-null  float64
#  12  opp_id         126314 non-null  object
#  13  opp_fran       126314 non-null  object
#  14  opp_pts        126314 non-null  int64
#  15  game_location  126314 non-null  object
#  16  game_result    126314 non-null  object
#  17  forecast       126314 non-null  float64
#  18  notes          5424 non-null    object
#  19  difference     126314 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(8), object(9)
# memory usage: 19.3+ MB

# %%
nba["game_location"].nunique()
# Out:
# 3

# %%
nba["game_location"].value_counts()
# Out:
# H    63138
# A    63138
# N       38
# Name: game_location, dtype: int64

# %%
nba["game_location"] = pd.Categorical(nba["game_location"])

# %%
nba["game_location"].dtype
# Out:
# CategoricalDtype(categories=['A', 'H', 'N'], ordered=False)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  win_equiv      126314 non-null  float64
#  12  opp_id         126314 non-null  object
#  13  opp_fran       126314 non-null  object
#  14  opp_pts        126314 non-null  int64
#  15  game_location  126314 non-null  category
#  16  game_result    126314 non-null  object
#  17  forecast       126314 non-null  float64
#  18  notes          5424 non-null    object
#  19  difference     126314 non-null  int64
# dtypes: category(1), datetime64[ns](1), float64(2), int64(8), object(8)
# memory usage: 18.4+ MB

# %%
rows_without_missing_data = nba.dropna()
rows_without_missing_data.shape
# Out:
# (5424, 20)

# %%
data_without_missing_columns = nba.dropna(axis=1)
data_without_missing_columns.shape
# Out:
# (126314, 19)

# %%
data_with_default_notes = nba.copy()
data_with_default_notes
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947 1946-11-01
# 1               1  194611010TRH   NBA        1     1947 1946-11-01
# 2               2  194611020CHS   NBA        0     1947 1946-11-02
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 4               3  194611020DTF   NBA        0     1947 1946-11-02
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015 2015-06-11
# 126310      63156  201506140GSW   NBA        0     2015 2015-06-14
# 126311      63156  201506140GSW   NBA        1     2015 2015-06-14
# 126312      63157  201506170CLE   NBA        0     2015 2015-06-16
# 126313      63157  201506170CLE   NBA        1     2015 2015-06-16
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# 1                1            0     NYK     Knicks   68      41.71    TRH
# 2                1            0     CHS      Stags   63      42.01    NYK
# 3                2            0     NYK     Knicks   47      40.69    CHS
# 4                1            0     DTF    Falcons   33      38.86    WSC
# ...            ...          ...     ...        ...  ...        ...    ...
# 126309         100            1     CLE  Cavaliers   82      60.31    GSW
# 126310         102            1     GSW   Warriors  104      68.01    CLE
# 126311         101            1     CLE  Cavaliers   91      60.01    GSW
# 126312         102            1     CLE  Cavaliers   97      59.29    GSW
# 126313         103            1     GSW   Warriors  105      68.52    CLE
#
#          opp_fran  opp_pts game_location game_result  forecast notes  \
# 0          Knicks       68             H           L      0.64   NaN
# 1         Huskies       66             A           W      0.36   NaN
# 2          Knicks       47             H           W      0.63   NaN
# 3           Stags       63             A           L      0.37   NaN
# 4        Capitols       50             H           L      0.64   NaN
# ...           ...      ...           ...         ...       ...   ...
# 126309   Warriors      103             H           L      0.55   NaN
# 126310  Cavaliers       91             H           W      0.77   NaN
# 126311   Warriors      104             A           L      0.23   NaN
# 126312   Warriors      105             H           L      0.48   NaN
# 126313  Cavaliers       97             A           W      0.52   NaN
#
#         difference
# 0               -2
# 1                2
# 2               16
# 3              -16
# 4              -17
# ...            ...
# 126309         -21
# 126310          13
# 126311         -13
# 126312          -8
# 126313           8
#
# [126314 rows x 20 columns]

# %%
data_with_default_notes["notes"].fillna(
    value = "no notes at all",
    inplace = True
)

# %%
data_with_default_notes["notes"].describe()
# Out:
# count              126314
# unique                232
# top       no notes at all
# freq               120890
# Name: notes, dtype: object

# %% [markdown]
# # Invalid Values

# %%
nba.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#        win_equiv    opp_pts   forecast  difference
# count  126314.00  126314.00  126314.00   126314.00
# mean       41.71     102.73       0.50        0.00
# std        10.63      14.81       0.22       13.37
# min        10.15       0.00       0.02      -68.00
# 25%        34.10      93.00       0.33       -9.00
# 50%        42.11     103.00       0.50        0.00
# 75%        49.64     112.00       0.67        9.00
# max        71.11     186.00       0.98       68.00

# %%
nba[nba["pts"] == 0]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 26684      13343  197210260VIR   ABA        1     1973 1972-10-26           7
#
#        is_playoffs team_id  fran_id  pts  win_equiv opp_id opp_fran  opp_pts  \
# 26684            0     DNR  Nuggets    0      40.41    VIR  Squires        2
#
#       game_location game_result  forecast                           notes  \
# 26684             A           L      0.33  at Richmond VA; forfeit to VIR
#
#        difference
# 26684          -2

# %% [markdown]
# # Inconsistent Values

# %%
nba[(nba["pts"] > nba["opp_pts"]) & (nba["game_result"] != "W")].empty
# Out:
# True

# %%
nba[(nba["pts"] < nba["opp_pts"]) & (nba["game_result"] != "L")].empty
# Out:
# True

# %% [markdown]
# # Combining Multiple DataSets

# %%
further_city_data = pd.DataFrame(
    {"revenue":[7000,3000],"employee_count":[2,2]},
    index = ["New York","Barcelona"]
)
further_city_data
# Out:
#            revenue  employee_count
# New York      7000               2
# Barcelona     3000               2

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
all_city_data = pd.concat([city_data,further_city_data],sort = False)
all_city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN
# New York      7000             2.0
# Barcelona     3000             2.0

# %%
city_countries = pd.DataFrame({
    "country":["Holland","Japan","Holland","Canada","Spain"],
    "capital":[1,1,0,0,0]},
    index = ["Amsterdam","Tokyo","Rotterdam","Toronto","Barcelona"]
)
city_countries
# Out:
#            country  capital
# Amsterdam  Holland        1
# Tokyo        Japan        1
# Rotterdam  Holland        0
# Toronto     Canada        0
# Barcelona    Spain        0

# %%
all_city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN
# New York      7000             2.0
# Barcelona     3000             2.0

# %%
cities = pd.concat([all_city_data,city_countries],axis = 1,sort = False)
cities
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3000.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
pd.concat([all_city_data,city_countries],axis = 1,sort = False, join = "inner")
# Out:
#            revenue  employee_count  country  capital
# Amsterdam     4200             5.0  Holland        1
# Tokyo         6500             8.0    Japan        1
# Toronto       8000             NaN   Canada        0
# Barcelona     3000             2.0    Spain        0

# %%
countries = pd.DataFrame({
    "population_millions":[17,127,37],
    "continent":["Europe","Asia","North America"]},
    index = ["Holland","Japan","Canada"]
)
countries
# Out:
#          population_millions      continent
# Holland                   17         Europe
# Japan                    127           Asia
# Canada                    37  North America

# %%
cities
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3000.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
pd.merge(cities,countries,left_on = "country",right_index = True,how = "inner")
# Out:
#            revenue  employee_count  country  capital  population_millions  \
# Amsterdam   4200.0             5.0  Holland      1.0                   17
# Rotterdam      NaN             NaN  Holland      0.0                   17
# Tokyo       6500.0             8.0    Japan      1.0                  127
# Toronto     8000.0             NaN   Canada      0.0                   37
#
#                continent
# Amsterdam         Europe
# Rotterdam         Europe
# Tokyo               Asia
# Toronto    North America

# %%
pd.merge(cities,countries,left_on = "country",right_index = True,how = "left")
# Out:
#            revenue  employee_count  country  capital  population_millions  \
# Amsterdam   4200.0             5.0  Holland      1.0                 17.0
# Tokyo       6500.0             8.0    Japan      1.0                127.0
# Toronto     8000.0             NaN   Canada      0.0                 37.0
# New York    7000.0             2.0      NaN      NaN                  NaN
# Barcelona   3000.0             2.0    Spain      0.0                  NaN
# Rotterdam      NaN             NaN  Holland      0.0                 17.0
#
#                continent
# Amsterdam         Europe
# Tokyo               Asia
# Toronto    North America
# New York             NaN
# Barcelona            NaN
# Rotterdam         Europe

# %% [markdown]
# # Visualizing Pandas DF

# %%
# %matplotlib inline

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947 1946-11-01
# 1               1  194611010TRH   NBA        1     1947 1946-11-01
# 2               2  194611020CHS   NBA        0     1947 1946-11-02
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 4               3  194611020DTF   NBA        0     1947 1946-11-02
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015 2015-06-11
# 126310      63156  201506140GSW   NBA        0     2015 2015-06-14
# 126311      63156  201506140GSW   NBA        1     2015 2015-06-14
# 126312      63157  201506170CLE   NBA        0     2015 2015-06-16
# 126313      63157  201506170CLE   NBA        1     2015 2015-06-16
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# 1                1            0     NYK     Knicks   68      41.71    TRH
# 2                1            0     CHS      Stags   63      42.01    NYK
# 3                2            0     NYK     Knicks   47      40.69    CHS
# 4                1            0     DTF    Falcons   33      38.86    WSC
# ...            ...          ...     ...        ...  ...        ...    ...
# 126309         100            1     CLE  Cavaliers   82      60.31    GSW
# 126310         102            1     GSW   Warriors  104      68.01    CLE
# 126311         101            1     CLE  Cavaliers   91      60.01    GSW
# 126312         102            1     CLE  Cavaliers   97      59.29    GSW
# 126313         103            1     GSW   Warriors  105      68.52    CLE
#
#          opp_fran  opp_pts game_location game_result  forecast notes  \
# 0          Knicks       68             H           L      0.64   NaN
# 1         Huskies       66             A           W      0.36   NaN
# 2          Knicks       47             H           W      0.63   NaN
# 3           Stags       63             A           L      0.37   NaN
# 4        Capitols       50             H           L      0.64   NaN
# ...           ...      ...           ...         ...       ...   ...
# 126309   Warriors      103             H           L      0.55   NaN
# 126310  Cavaliers       91             H           W      0.77   NaN
# 126311   Warriors      104             A           L      0.23   NaN
# 126312   Warriors      105             H           L      0.48   NaN
# 126313  Cavaliers       97             A           W      0.52   NaN
#
#         difference
# 0               -2
# 1                2
# 2               16
# 3              -16
# 4              -17
# ...            ...
# 126309         -21
# 126310          13
# 126311         -13
# 126312          -8
# 126313           8
#
# [126314 rows x 20 columns]

# %%
nba[nba["fran_id"] == "Knicks"].groupby("year_id")["pts"].sum()
# Out:
# year_id
# 1947    4234
# 1948    3815
# 1949    5253
# 1950    5924
# 1951    6814
#         ...
# 2011    9097
# 2012    6872
# 2013    9259
# 2014    8084
# 2015    7535
# Name: pts, Length: 69, dtype: int64

# %%
nba[nba["fran_id"] == "Knicks"].groupby("year_id")["pts"].sum().plot()
# Out:
# <AxesSubplot:xlabel='year_id'>

# %%
nba["fran_id"].value_counts().head(10)
# Out:
# Lakers      6024
# Celtics     5997
# Knicks      5769
# Warriors    5657
# Pistons     5650
# Sixers      5644
# Hawks       5572
# Kings       5475
# Wizards     4582
# Spurs       4309
# Name: fran_id, dtype: int64

# %%
nba["fran_id"].value_counts().head(10).plot(kind = "bar")
# Out:
# <AxesSubplot:>
